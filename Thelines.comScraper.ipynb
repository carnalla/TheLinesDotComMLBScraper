# %% [markdown]
# ## Sources for this block:
# - https://stackoverflow.com/questions/42863240/how-to-get-round-the-http-error-403-forbidden-with-urllib-request-using-python

# %%
import urllib.request


url = 'https://metabet.static.api.areyouwatchingthis.com/api/odds.json?apiKey=219f64094f67ed781035f5f7a08840fc&location=TN&leagueCode=BBM'

# Open the URL as Browser, not as python urllib

page=urllib.request.Request(url,headers={'User-Agent': 'Mozilla/5.0'})
infile=urllib.request.urlopen(page).read()
data = infile.decode('ISO-8859-1') # Read the content as string decoded with ISO-8859-1

# Print the data to the screen

print(data)
# Out:
# {"meta":{"code":200,"count":17,"description":"Odds for [BBM] games"},"results":[{"gameID":503717,"team1Score":5,"date":1654121100000,"team2ID":13385,"pointsLevel":"Guarded","team2Initials":"PHI","team1Color":"202020","team2Score":2,"points":74,"team1Name":"Giants","team2City":"Philadelphia","team1City":"San Francisco","odds":[{"date":1654128747000,"overUnder":9.5,"spreadLine2":2.05,"provider":"CONSENSUS","spreadLine1":1.74777,"overUnderLineOver":1.77037,"overUnderLineUnder":2.0152,"moneyLine2":5.35,"spread":2.5,"moneyLine1":1.14589},{"date":1654121958000,"overUnder":7.5,"spreadLine2":2.55,"provider":"SPORT_888","spreadLine1":1.444,"overUnderLineOver":2.05,"overUnderLineUnder":1.7,"moneyLine2":1.8,"url":"https://go.metabet.io/bet/503717/sport_888","spread":-1.5,"moneyLine1":2},{"date":1654128660000,"overUnder":10,"spreadLine2":1.96154,"provider":"BET_RIVERS_PA","spreadLine1":1.77519,"overUnderLineOver":1.91743,"overUnderLineUnder":1.81967,"moneyLine2":5.1,"url":"https://go.metabet.io/bet/503717/bet_rivers_pa","spread":2.5,"moneyLine1":1.14925},{"date":1654128572000,"overUnder":10,"spreadLine2":1.92593,"provider":"BET_RIVERS_AZ","spreadLine1":1.84746,"overUnderLineOver":1.90909,"overUnderLineUnder":1.86957,"moneyLine2":4.9,"url":"https://go.metabet.io/bet/503717/bet_rivers_az","spread":2.5,"moneyLine1":1.17857},{"date":1654128677000,"overUnder":10,"spreadLine2":2,"provider":"BET_RIVERS_CO","spreadLine1":1.7874,"overUnderLineOver":1.93458,"overUnderLineUnder":1.83333,"moneyLine2":5.2,"url":"https://go.metabet.io/bet/503717/bet_rivers_co","spread":2.5,"moneyLine1":1.16},{"date":1654128537000,"overUnder":10,"spreadLine2":1.97087,"provider":"BET_RIVERS_IA","spreadLine1":1.8,"overUnderLineOver":1.86957,"overUnderLineUnder":1.89286,"moneyLine2":5,"url":"https://go.metabet.io/bet/503717/bet_rivers_ia
# %%
import json
import pandas as pd

data = json.loads(data)
games = data['meta']['count']

# %%
colNames = ['Home/Away', 'Team', 'FanDuel ML Odds', 'DraftKings ML Odds']
summary = pd.DataFrame(columns = colNames)

def get_amOdds(decimal):
    
    if decimal >= 2: amOdds = (decimal - 1) * 100
    if decimal < 2: amOdds = -100 / (decimal -1)
        
    return amOdds

for game in range(0, games):

    gameID = data['results'][game]['gameID']
    visTem = data['results'][game]['team1Name']
    homTem = data['results'][game]['team2Name']

    book = data['results'][game]['odds']

    DKbook = next((sub for sub in book if sub['provider'] == 'DRAFTKINGS'), None)
    FDbook = next((sub for sub in book if sub['provider'] == 'FANDUEL'), None)

    if bool(DKbook) == True:
    
        DKvisML = round(get_amOdds(DKbook['moneyLine1']))
        DKhomML = round(get_amOdds(DKbook['moneyLine2']))

    else:
        
        DKvisML = str('-')
        DKhomML = str('-')
        
    if bool(FDbook) == True:
        
        FDvisML = round(get_amOdds(FDbook['moneyLine1']))
        FDhomML = round(get_amOdds(FDbook['moneyLine2']))

    else:

        FDvisML = str('-')
        FDhomML = str('-')

    summary.loc[len(summary)] = [str('Visitor'), visTem, FDvisML, DKvisML]
    summary.loc[len(summary)] = [str('Home'), homTem, FDhomML, DKhomML]
    
summary
# Out:
#    Home/Away       Team FanDuel ML Odds DraftKings ML Odds
# 0    Visitor     Giants            -650               -725
# 1       Home   Phillies             420                450
# 2    Visitor   Mariners             174                360
# 3       Home    Orioles            -225               -550
# 4    Visitor  White Sox             590                210
# 5       Home  Blue Jays           -1100               -280
# 6    Visitor       Reds             450                270
# 7       Home    Red Sox            -700               -385
# 8    Visitor      Twins             184                185
# 9       Home     Tigers            -240               -245
# 10   Visitor       Rays            -112               -110
# 11      Home    Rangers            -112               -120
# 12   Visitor    Brewers            -112               -110
# 13      Home       Cubs            -112               -120
# 14   Visitor    Pirates             188                210
# 15      Home    Dodgers            -250               -280
# 16   Visitor      Twins            -126               -130
# 17      Home     Tigers             108                110
# 18   Visitor       Rays            -124               -125
# 19      Home    Rangers             106                105
# 20   Visitor  White Sox             160                150
# 21      Home  Blue Jays            -190               -170
# 22   Visitor  Nationals             110                110
# 23      Home       Reds            -130               -130
# 24   Visitor     Angels               -                100
# 25      Home    Yankees               -               -120
# 26   Visitor   Mariners            -124               -120
# 27      Home    Orioles             106                100
# 28   Visitor     Padres               -                100
# 29      Home    Brewers               -               -120
# 30   Visitor  Cardinals               -               -110
# 31      Home       Cubs               -               -110
# 32   Visitor     Braves               -               -145
# 33      Home    Rockies               -                125
